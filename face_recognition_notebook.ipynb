# %%
# !pip install ultralytics insightface opencv-python-headless onnxruntime streamlit pyngrok -q
print("All packages installed!")
# Out:
# All packages installed!

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.makedirs('/content/face_tracker/logs/entries', exist_ok=True)
os.makedirs('/content/face_tracker/logs/exits', exist_ok=True)
print("Folders ready!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Folders ready!

# %%
import json

config = {
    "detection_skip_frames": 5,
    "similarity_threshold": 0.55,
    "stability_frames": 1,
    "video_folder": "/content/drive/MyDrive/Video Datasets",
    "db_path": "/content/face_tracker/visitors.db",
    "log_dir": "/content/face_tracker/logs",
    "exit_timeout_frames": 30,
    "rtsp_url": ""
}

with open('/content/face_tracker/config.json', 'w') as f:
    json.dump(config, f, indent=2)
print(" Config created!")
print(json.dumps(config, indent=2))
# Out:
#  Config created!
# {
#   "detection_skip_frames": 5,
#   "similarity_threshold": 0.55,
#   "stability_frames": 1,
#   "video_folder": "/content/drive/MyDrive/Video Datasets",
#   "db_path": "/content/face_tracker/visitors.db",
#   "log_dir": "/content/face_tracker/logs",
#   "exit_timeout_frames": 30,
#   "rtsp_url": ""
# }

# %%
import sqlite3
import json as jsonlib
import numpy as np
import shutil
import os

os.makedirs('/content/face_tracker/logs/entries', exist_ok=True)
os.makedirs('/content/face_tracker/logs/exits', exist_ok=True)
print("Folders ready!")

# Restore DB from Drive if Colab restarted
drive_db = '/content/drive/MyDrive/visitors.db'
local_db  = '/content/face_tracker/visitors.db'
if not os.path.exists(local_db) and os.path.exists(drive_db):
    shutil.copy(drive_db, local_db)
    print("Restored DB from Drive!")
else:
    print("Starting with local DB!")

def init_db(db_path):
    conn = sqlite3.connect(db_path)
    conn.execute('''
        CREATE TABLE IF NOT EXISTS visitors (
            id          INTEGER PRIMARY KEY AUTOINCREMENT,
            face_id     TEXT,
            event_type  TEXT,
            timestamp   TEXT,
            image_path  TEXT,
            video_file  TEXT
        )
    ''')
    conn.execute('''
        CREATE TABLE IF NOT EXISTS unique_visitors (
            face_id      TEXT PRIMARY KEY,
            first_seen   TEXT,
            last_seen    TEXT,
            total_visits INTEGER DEFAULT 1
        )
    ''')
    conn.execute('''
        CREATE TABLE IF NOT EXISTS embeddings (
            face_id   TEXT PRIMARY KEY,
            embedding TEXT
        )
    ''')
    conn.commit()
    return conn

def db_log(conn, face_id, event_type, timestamp, image_path, video_file):
    conn.execute(
        "INSERT INTO visitors (face_id, event_type, timestamp, image_path, video_file) VALUES (?,?,?,?,?)",
        (face_id, event_type, timestamp, image_path, video_file)
    )
    conn.commit()

def db_register_unique(conn, face_id, timestamp):
    conn.execute(
        "INSERT OR IGNORE INTO unique_visitors (face_id, first_seen, last_seen) VALUES (?,?,?)",
        (face_id, timestamp, timestamp)
    )
    conn.execute(
        "UPDATE unique_visitors SET last_seen=?, total_visits=total_visits+1 WHERE face_id=?",
        (timestamp, face_id)
    )
    conn.commit()

def save_embedding(conn, face_id, embedding):
    emb_str = jsonlib.dumps(embedding.tolist())
    conn.execute(
        "INSERT OR REPLACE INTO embeddings (face_id, embedding) VALUES (?,?)",
        (face_id, emb_str)
    )
    conn.commit()

def load_embeddings(conn):
    try:
        rows   = conn.execute("SELECT face_id, embedding FROM embeddings").fetchall()
        loaded = {}
        for face_id, emb_str in rows:
            loaded[face_id] = np.array(jsonlib.loads(emb_str))
        if loaded:
            print(f"Loaded {len(loaded)} existing embeddings from DB!")
        else:
            print("No existing embeddings — starting fresh!")
        return loaded
    except Exception as e:
        print(f"Starting fresh! ({e})")
        return {}

def get_unique_count(conn):
    row = conn.execute("SELECT COUNT(*) FROM unique_visitors").fetchone()
    return row[0] if row else 0

conn = init_db('/content/face_tracker/visitors.db')
print("Database ready!")
# Out:
# Folders ready!
# Starting with local DB!
# Database ready!

# %%
from ultralytics import YOLO
import cv2
import urllib.request

class YOLOFaceDetector:

    def __init__(self):
        model_path = '/content/face_tracker/yolov8n-face.pt'
        if not os.path.exists(model_path):
            print("Downloading YOLOv8 face model from HuggingFace...")
            try:
                urllib.request.urlretrieve(
                    'https://huggingface.co/arnabdhar/YOLOv8-Face-Detection'
                    '/resolve/main/model.pt',
                    model_path
                )
                size_mb = os.path.getsize(model_path) / (1024 * 1024)
                if size_mb < 1:
                    raise Exception("File too small — likely a redirect page")
                print(f"Downloaded: {size_mb:.1f} MB")
            except Exception as e:
                print(f"Download failed ({e}), using YOLOv8n fallback...")
                model_path = 'yolov8n.pt'

        self.model         = YOLO(model_path)
        self.is_face_model = 'yolov8n.pt' not in model_path
        print(f"YOLO loaded! Dedicated face model: {self.is_face_model}")

    def detect(self, frame):
        if self.is_face_model:
            results = self.model(frame, verbose=False, conf=0.5)
        else:
            # Generic model — detect persons, crop top 35% as face region
            results = self.model(frame, verbose=False, conf=0.5, classes=[0])

        boxes = []
        for r in results:
            for box in r.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                if not self.is_face_model:
                    h  = y2 - y1
                    y2 = y1 + int(h * 0.35)
                # Small padding around detected face
                x1 = max(0, x1 - 5)
                y1 = max(0, y1 - 5)
                x2 = min(frame.shape[1], x2 + 5)
                y2 = min(frame.shape[0], y2 + 5)
                if x2 > x1 and y2 > y1:
                    boxes.append((x1, y1, x2, y2))
        return boxes


yolo = YOLOFaceDetector()
# Out:
# YOLO loaded! Dedicated face model: True

# %%
import insightface
import numpy as np

class FaceRecognizer:

    def __init__(self, conn):
        self.app = insightface.app.FaceAnalysis(
            providers=['CPUExecutionProvider']
        )
        self.app.prepare(ctx_id=0, det_size=(320, 320))
        self.known_faces = load_embeddings(conn)
        print(" InsightFace loaded!")

    def get_embedding(self, face_crop):
        """Extract a 512-dim face embedding from a crop."""
        if face_crop.shape[0] < 20 or face_crop.shape[1] < 20:
            return None
        try:
            # Upscale + sharpen for better embedding on small CCTV crops
            upscaled  = cv2.resize(face_crop, (112, 112),
                                   interpolation=cv2.INTER_CUBIC)
            kernel    = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
            sharpened = cv2.filter2D(upscaled, -1, kernel)

            faces = self.app.get(sharpened)
            if faces:
                return faces[0].embedding
            # Fallback: try original crop
            faces = self.app.get(face_crop)
            if faces:
                return faces[0].embedding
        except Exception:
            pass
        return None

    def find_match(self, embedding, threshold):

        best_sim = -1
        best_id  = None
        for face_id, known_emb in self.known_faces.items():
            sim = float(
                np.dot(embedding, known_emb) /
                (np.linalg.norm(embedding) * np.linalg.norm(known_emb))
            )
            if sim > best_sim:
                best_sim = sim
                best_id  = face_id
        if best_sim >= threshold:
            return best_id
        return None

    def register(self, face_id, embedding):
        """Add a new face embedding to the in-memory store."""
        self.known_faces[face_id] = embedding

    def update_embedding(self, face_id, new_embedding):

        if face_id in self.known_faces:
            alpha = 0.3
            updated = (
                alpha * new_embedding +
                (1 - alpha) * self.known_faces[face_id]
            )
            # Re-normalise to unit vector for cosine similarity
            self.known_faces[face_id] = (
                updated / np.linalg.norm(updated)
            )
        else:
            self.register(face_id, new_embedding)


recognizer = FaceRecognizer(conn)
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (320, 320)
# Loaded 139 existing embeddings from DB!
#  InsightFace loaded!

# %%
class CentroidTracker:

    def __init__(self, exit_timeout=30, stability_frames=8):
        self.tracks           = {}
        self.next_id          = 0
        self.exit_timeout     = exit_timeout
        self.stability_frames = stability_frames

    def _centroid(self, box):
        x1, y1, x2, y2 = box
        return ((x1 + x2) // 2, (y1 + y2) // 2)

    def _dist(self, c1, c2):
        return ((c1[0] - c2[0]) ** 2 + (c1[1] - c2[1]) ** 2) ** 0.5

    def _iou(self, a, b):
        xA = max(a[0], b[0]); yA = max(a[1], b[1])
        xB = min(a[2], b[2]); yB = min(a[3], b[3])
        inter = max(0, xB - xA) * max(0, yB - yA)
        if inter == 0:
            return 0.0
        area_a = (a[2] - a[0]) * (a[3] - a[1])
        area_b = (b[2] - b[0]) * (b[3] - b[1])
        return inter / float(area_a + area_b - inter)

    def _score(self, track, cent, box):

        dist = self._dist(track['centroid'], cent)
        iou  = self._iou(track['box'], box)
        return dist * (1 - iou * 0.5)

    def update(self, boxes, frame, detection_ran):

        exited      = []
        current     = [(self._centroid(b), b) for b in boxes]
        matched_det = set()

        # ── Match detections to existing tracks ──────────────
        for tid, track in self.tracks.items():
            best_score = 80   # distance threshold — tune if needed
            best_i     = None
            for i, (cent, box) in enumerate(current):
                if i in matched_det:
                    continue
                score = self._score(track, cent, box)
                if score < best_score:
                    best_score = score
                    best_i     = i

            if best_i is not None:
                cent, box         = current[best_i]
                track['centroid'] = cent
                track['box']      = box
                track['missing']  = 0
                track['age']      = track.get('age', 0) + 1
                x1, y1, x2, y2   = box
                crop              = frame[y1:y2, x1:x2]
                if crop.size > 0:
                    track['last_crop'] = crop.copy()
                matched_det.add(best_i)
            else:
                # Only penalise when detection actually ran
                if detection_ran:
                    track['missing'] += 1

        # ── Register unmatched detections as new tracks ───────
        new_track_ids = []
        for i, (cent, box) in enumerate(current):
            if i not in matched_det:
                x1, y1, x2, y2 = box
                crop = frame[y1:y2, x1:x2]
                self.tracks[self.next_id] = {
                    'centroid':  cent,
                    'box':       box,
                    'face_id':   None,
                    'missing':   0,
                    'age':       1,
                    'last_crop': crop.copy() if crop.size > 0 else None
                }
                new_track_ids.append(self.next_id)
                self.next_id += 1

        # ── Declare exits for long-missing tracks ─────────────
        to_remove = []
        for tid, track in self.tracks.items():
            if track['missing'] >= self.exit_timeout:
                exited.append((tid, track['face_id'], track.get('last_crop')))
                to_remove.append(tid)
        for tid in to_remove:
            del self.tracks[tid]

        return self.tracks, new_track_ids, exited


print("Centroid + IoU Tracker ready!")
# Out:
# Centroid + IoU Tracker ready!

# %%
os.makedirs('/content/face_tracker/logs', exist_ok=True)
import logging
from datetime import datetime

logging.basicConfig(
    filename='/content/face_tracker/logs/events.log',
    level=logging.INFO,
    format='%(asctime)s - %(message)s'
)


def save_face_image(face_crop, face_id, event_type, log_dir):
    date_str = datetime.now().strftime("%Y-%m-%d")
    folder   = f'{log_dir}/{event_type}s/{date_str}'
    os.makedirs(folder, exist_ok=True)
    ts   = datetime.now().strftime("%H-%M-%S-%f")
    path = f'{folder}/{face_id}_{ts}.jpg'
    cv2.imwrite(path, face_crop)
    return path


def log_entry(face_id, img_path, video_file):
    logging.info(
        f"ENTRY               | face_id={face_id} | "
        f"video={video_file} | img={img_path}"
    )

def log_exit(face_id, img_path, video_file):
    logging.info(
        f"EXIT                | face_id={face_id} | "
        f"video={video_file} | img={img_path}"
    )

def log_embedding(face_id, video_file):
    logging.info(
        f"EMBEDDING_GENERATED | face_id={face_id} | video={video_file}"
    )

def log_tracking(face_id, track_id, video_file):
    logging.info(
        f"TRACKING            | face_id={face_id} | "
        f"track_id={track_id} | video={video_file}"
    )

def log_reidentified(face_id, video_file):
    logging.info(
        f"RE_IDENTIFIED       | face_id={face_id} | video={video_file}"
    )


print(" Logger ready!")
# Out:
#  Logger ready!

# %%
import uuid
from datetime import datetime

with open('/content/face_tracker/config.json') as f:
    config = json.load(f)

rtsp_url         = config.get('rtsp_url', '').strip()
video_folder     = config['video_folder']
skip             = config['detection_skip_frames']
similarity_thr   = config['similarity_threshold']
stability_frames = config['stability_frames']

if rtsp_url:
    all_videos = ['LIVE_RTSP']
    print(f" RTSP mode: {rtsp_url}")
else:
    all_videos = sorted([
        f for f in os.listdir(video_folder) if f.endswith('.mp4')
    ])
    print(f" Found {len(all_videos)} video(s)\n")

frame_count = 0

for video_name in all_videos:

    if rtsp_url:
        cap = cv2.VideoCapture(rtsp_url)
    else:
        cap = cv2.VideoCapture(os.path.join(video_folder, video_name))

    if not cap.isOpened():
        print(f" Could not open: {video_name}")
        continue

    print(f" Processing: {video_name}")
    video_frame   = 0
    last_boxes    = []
    detection_ran = False

    tracker = CentroidTracker(
        exit_timeout=config['exit_timeout_frames'],
        stability_frames=stability_frames
    )

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        video_frame += 1

        # ── Step 1: YOLO Detection every N frames ────────────
        detection_ran = (frame_count % skip == 0)
        if detection_ran:
            last_boxes = yolo.detect(frame)
        boxes = last_boxes  # reuse last known boxes on skipped frames

        # ── Step 2: Update Tracker ────────────────────────────
        active_tracks, new_track_ids, exited = tracker.update(
            boxes, frame, detection_ran
        )

        # ── Step 3: Handle New Tracks (with stability gate) ───
        for tid in new_track_ids:
            track = active_tracks.get(tid)
            if track is None:
                continue

            if track.get('age', 1) < stability_frames:
                continue

            crop = track.get('last_crop')
            if crop is None or crop.size == 0:
                continue

            # Get embedding for re-ID check across track breaks
            embedding = recognizer.get_embedding(crop)
            log_embedding(f"track_{tid}", video_name)

            # Check if this is a re-entering known person
            matched_face_id = None
            if embedding is not None:
                matched_face_id = recognizer.find_match(
                    embedding, similarity_thr
                )

            if matched_face_id is not None:
                # ── Known person re-entered ───────────────────
                # Assign same face_id, log entry, but DO NOT
                # increment unique visitor count.
                face_id          = matched_face_id
                track['face_id'] = face_id

                # Update embedding with new angle/lighting data
                if embedding is not None:
                    recognizer.update_embedding(face_id, embedding)
                    save_embedding(conn, face_id,
                                   recognizer.known_faces[face_id])

                timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                img_path  = save_face_image(
                    crop, face_id, 'entry', config['log_dir']
                )
                db_log(conn, face_id, 'entry', timestamp,
                       img_path, video_name)
                log_reidentified(face_id, video_name)
                print(f"   RE-ENTRY: {face_id} (not counted again)")

            else:
                # ── Genuinely new person ──────────────────────
                face_id          = str(uuid.uuid4())[:8]
                track['face_id'] = face_id

                if embedding is not None:
                    recognizer.register(face_id, embedding)
                    save_embedding(conn, face_id, embedding)

                timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                img_path  = save_face_image(
                    crop, face_id, 'entry', config['log_dir']
                )
                db_log(conn, face_id, 'entry', timestamp,
                       img_path, video_name)
                db_register_unique(conn, face_id, timestamp)
                log_entry(face_id, img_path, video_name)

                unique_count = get_unique_count(conn)
                print(
                    f"   NEW: {face_id} | "
                    f"Total unique: {unique_count}"
                )

        # ── Step 4: Log Active Tracking ───────────────────────
        for tid, track in active_tracks.items():
            if track['face_id']:
                log_tracking(track['face_id'], tid, video_name)

        # ── Step 5: Log Exits ─────────────────────────────────
        for tid, face_id, exit_crop in exited:
            if face_id is None:
                continue
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            exit_img  = ''
            if exit_crop is not None and exit_crop.size > 0:
                exit_img = save_face_image(
                    exit_crop, face_id, 'exit', config['log_dir']
                )
            db_log(conn, face_id, 'exit', timestamp,
                   exit_img, video_name)
            log_exit(face_id, exit_img, video_name)
            print(f"   EXIT: {face_id}")

    # ── End of video: log remaining tracks as exits ───────────
    for tid, track in tracker.tracks.items():
        if track['face_id']:
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            exit_img  = ''
            crop      = track.get('last_crop')
            if crop is not None and crop.size > 0:
                exit_img = save_face_image(
                    crop, track['face_id'], 'exit', config['log_dir']
                )
            db_log(conn, track['face_id'], 'exit',
                   timestamp, exit_img, video_name)
            log_exit(track['face_id'], exit_img, video_name)

    cap.release()
    print(f"   Done: {video_name} | Frames processed: {video_frame}\n")

print(f"\n ALL DONE!")
print(f" Total Unique Visitors: {get_unique_count(conn)}")

print("\n PER VIDEO SUMMARY:")
print("-" * 50)
rows = conn.execute("""
    SELECT video_file, COUNT(*) as entries
    FROM visitors
    WHERE event_type = 'entry'
    GROUP BY video_file
    ORDER BY video_file
""").fetchall()
for video, count in rows:
    print(f"  {video}: {count} entries")
print("-" * 50)
# Out:
#  Found 23 video(s)
#
#  Processing: record_20250620_183903.mp4
#    RE-ENTRY: 82e08fd7 (not counted again)
#    EXIT: 82e08fd7
#    RE-ENTRY: 55889152 (not counted again)
#    RE-ENTRY: 3447534a (not counted again)
#    RE-ENTRY: 4e6615c7 (not counted again)
#    RE-ENTRY: 90ed8720 (not counted again)
#    RE-ENTRY: 0e7b5edc (not counted again)
#    EXIT: 55889152
#    EXIT: 4e6615c7
#    EXIT: 90ed8720
#    NEW: 95e78fe4 | Total unique: 12
#    RE-ENTRY: 401d0d62 (not counted again)
#    RE-ENTRY: 95e78fe4 (not counted again)
#    RE-ENTRY: 401d0d62 (not counted again)
#    RE-ENTRY: 401d0d62 (not counted again)
#    RE-ENTRY: 95e78fe4 (not counted again)
#    RE-ENTRY: 031911eb (not counted again)
#    RE-ENTRY: 031911eb (not counted again)
#    RE-ENTRY: 12c0f4b3 (not counted again)
#    RE-ENTRY: 5b95d79b (not counted again)
#    RE-ENTRY: 5b95d79b (not counted again)
#    RE-ENTRY: 5b95d79b (not counted again)
#    RE-ENTRY: 5b95d79b (not counted again)
#    EXIT: 0e7b5edc
#    EXIT: 3447534a
#    EXIT: 95e78fe4
#    EXIT: 401d0d62
#    EXIT: 95e78fe4
#    EXIT: 401d0d62
#    EXIT: 401d0d62
#    EXIT: 95e78fe4
#    EXIT: 031911eb
#    EXIT: 031911eb
#    EXIT: 5b95d79b
#    EXIT: 5b95d79b
#    EXIT: 5b95d79b
#    EXIT: 5b95d79b
#    EXIT: 12c0f4b3
#    RE-ENTRY: 8839261e (not counted again)
#    RE-ENTRY: 8839261e (not counted again)
#    Done: record_20250620_183903.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184049.mp4
#    NEW: 6c51e5c9 | Total unique: 13
#    NEW: da9fcfc0 | Total unique: 14
#    EXIT: 6c51e5c9
#    EXIT: da9fcfc0
#    Done: record_20250620_184049.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184302.mp4
#    NEW: c11f7c28 | Total unique: 15
#    NEW: 477c1db3 | Total unique: 16
#    EXIT: c11f7c28
#    EXIT: 477c1db3
#    Done: record_20250620_184302.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184403.mp4
#    NEW: ca958685 | Total unique: 17
#    NEW: df3f0a14 | Total unique: 18
#    NEW: 8dcd418e | Total unique: 19
#    NEW: 5aa78752 | Total unique: 20
#    NEW: b62df85c | Total unique: 21
#    NEW: 6acd374e | Total unique: 22
#    NEW: 321cf14a | Total unique: 23
#    RE-ENTRY: 321cf14a (not counted again)
#    NEW: cd7e11b2 | Total unique: 24
#    EXIT: 8dcd418e
#    Done: record_20250620_184403.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184504.mp4
#    NEW: 517aa280 | Total unique: 25
#    NEW: 548d77df | Total unique: 26
#    RE-ENTRY: 548d77df (not counted again)
#    RE-ENTRY: 548d77df (not counted again)
#    RE-ENTRY: 548d77df (not counted again)
#    RE-ENTRY: 548d77df (not counted again)
#    RE-ENTRY: 548d77df (not counted again)
#    NEW: 84e2379d | Total unique: 27
#    EXIT: 517aa280
#    EXIT: 548d77df
#    EXIT: 548d77df
#    EXIT: 548d77df
#    EXIT: 548d77df
#    EXIT: 548d77df
#    EXIT: 548d77df
#    EXIT: 84e2379d
#    Done: record_20250620_184504.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184605.mp4
#    Done: record_20250620_184605.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184705.mp4
#    NEW: 85134fda | Total unique: 28
#    EXIT: 85134fda
#    Done: record_20250620_184705.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184807.mp4
#    NEW: 323cf6b2 | Total unique: 29
#    NEW: 3ae03e98 | Total unique: 30
#    NEW: f782a717 | Total unique: 31
#    NEW: 97e6cef7 | Total unique: 32
#    NEW: f613a9a8 | Total unique: 33
#    EXIT: 323cf6b2
#    EXIT: 3ae03e98
#    EXIT: 97e6cef7
#    EXIT: f613a9a8
#    EXIT: f782a717
#    NEW: bf4310d5 | Total unique: 34
#    NEW: f83e4b99 | Total unique: 35
#    NEW: c564c46a | Total unique: 36
#    NEW: 5fbd746b | Total unique: 37
#    NEW: 9a83ba00 | Total unique: 38
#    NEW: e0d5e9a6 | Total unique: 39
#    NEW: a2a7ac44 | Total unique: 40
#    RE-ENTRY: a2a7ac44 (not counted again)
#    RE-ENTRY: a2a7ac44 (not counted again)
#    EXIT: f83e4b99
#    EXIT: bf4310d5
#    EXIT: c564c46a
#    EXIT: 5fbd746b
#    EXIT: 9a83ba00
#    EXIT: e0d5e9a6
#    EXIT: a2a7ac44
#    EXIT: a2a7ac44
#    EXIT: a2a7ac44
#    NEW: bd9a5a0b | Total unique: 41
#    NEW: 2fbb48c0 | Total unique: 42
#    NEW: 42401b1b | Total unique: 43
#    NEW: c547d33f | Total unique: 44
#    NEW: 5fd529ee | Total unique: 45
#    NEW: 2244385e | Total unique: 46
#    NEW: f22bbc3a | Total unique: 47
#    NEW: f1680440 | Total unique: 48
#    NEW: 1d15c164 | Total unique: 49
#    EXIT: bd9a5a0b
#    EXIT: 2fbb48c0
#    NEW: 713843e5 | Total unique: 50
#    EXIT: c547d33f
#    NEW: 9b8bb65c | Total unique: 51
#    EXIT: 5fd529ee
#    NEW: e9575b32 | Total unique: 52
#    NEW: dcae6e7e | Total unique: 53
#    NEW: 68493154 | Total unique: 54
#    EXIT: 42401b1b
#    NEW: 4401272e | Total unique: 55
#    EXIT: f22bbc3a
#    NEW: 5863746a | Total unique: 56
#    EXIT: 1d15c164
#    EXIT: 713843e5
#    Done: record_20250620_184807.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_184907.mp4
#    NEW: 50f2837e | Total unique: 57
#    NEW: d4239552 | Total unique: 58
#    NEW: bc2dd8ed | Total unique: 59
#    EXIT: 50f2837e
#    EXIT: d4239552
#    EXIT: bc2dd8ed
#    Done: record_20250620_184907.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_185008.mp4
#    NEW: 01fec4c8 | Total unique: 60
#    NEW: 82b841f6 | Total unique: 61
#    RE-ENTRY: 82b841f6 (not counted again)
#    NEW: 45d8d102 | Total unique: 62
#    NEW: 93c6dcb6 | Total unique: 63
#    RE-ENTRY: 93c6dcb6 (not counted again)
#    EXIT: 01fec4c8
#    EXIT: 82b841f6
#    EXIT: 82b841f6
#    NEW: 627be10c | Total unique: 64
#    EXIT: 45d8d102
#    EXIT: 93c6dcb6
#    EXIT: 93c6dcb6
#    EXIT: 627be10c
#    NEW: 992bac8a | Total unique: 65
#    NEW: ae0326a7 | Total unique: 66
#    EXIT: 992bac8a
#    EXIT: ae0326a7
#    Done: record_20250620_185008.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_185109.mp4
#    NEW: efafac95 | Total unique: 67
#    EXIT: efafac95
#    Done: record_20250620_185109.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_185210.mp4
#    NEW: 72ec6cd8 | Total unique: 68
#    NEW: 779d3b3b | Total unique: 69
#    RE-ENTRY: 779d3b3b (not counted again)
#    NEW: 10065524 | Total unique: 70
#    NEW: 1270a30c | Total unique: 71
#    EXIT: 72ec6cd8
#    EXIT: 779d3b3b
#    EXIT: 779d3b3b
#    NEW: 2a905df1 | Total unique: 72
#    NEW: 3aa1fe93 | Total unique: 73
#    RE-ENTRY: 2a905df1 (not counted again)
#    RE-ENTRY: 2a905df1 (not counted again)
#    NEW: c2a6314f | Total unique: 74
#    Done: record_20250620_185210.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190324.mp4
#    NEW: 97f6b54c | Total unique: 75
#    NEW: 9e501b17 | Total unique: 76
#    RE-ENTRY: 97f6b54c (not counted again)
#    RE-ENTRY: 97f6b54c (not counted again)
#    RE-ENTRY: 97f6b54c (not counted again)
#    RE-ENTRY: 97f6b54c (not counted again)
#    RE-ENTRY: 97f6b54c (not counted again)
#    RE-ENTRY: 97f6b54c (not counted again)
#    RE-ENTRY: 97f6b54c (not counted again)
#    NEW: 90d597f1 | Total unique: 77
#    RE-ENTRY: 90d597f1 (not counted again)
#    EXIT: 97f6b54c
#    EXIT: 9e501b17
#    EXIT: 97f6b54c
#    EXIT: 97f6b54c
#    EXIT: 97f6b54c
#    EXIT: 97f6b54c
#    EXIT: 97f6b54c
#    EXIT: 97f6b54c
#    EXIT: 97f6b54c
#    NEW: c36469f7 | Total unique: 78
#    EXIT: 90d597f1
#    EXIT: 90d597f1
#    NEW: 258d00b6 | Total unique: 79
#    NEW: b2be0a26 | Total unique: 80
#    NEW: d3748918 | Total unique: 81
#    RE-ENTRY: b2be0a26 (not counted again)
#    RE-ENTRY: d3748918 (not counted again)
#    RE-ENTRY: d3748918 (not counted again)
#    RE-ENTRY: b2be0a26 (not counted again)
#    RE-ENTRY: b2be0a26 (not counted again)
#    RE-ENTRY: b2be0a26 (not counted again)
#    RE-ENTRY: b2be0a26 (not counted again)
#    EXIT: c36469f7
#    EXIT: 258d00b6
#    EXIT: b2be0a26
#    EXIT: d3748918
#    EXIT: d3748918
#    EXIT: b2be0a26
#    EXIT: d3748918
#    EXIT: b2be0a26
#    EXIT: b2be0a26
#    EXIT: b2be0a26
#    EXIT: b2be0a26
#    NEW: 5d29967e | Total unique: 82
#    NEW: 2b39ea18 | Total unique: 83
#    EXIT: 5d29967e
#    EXIT: 2b39ea18
#    Done: record_20250620_190324.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190425.mp4
#    NEW: 0ff9d683 | Total unique: 84
#    NEW: 2a26b8ac | Total unique: 85
#    RE-ENTRY: 2a26b8ac (not counted again)
#    RE-ENTRY: 2a26b8ac (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    RE-ENTRY: 0ff9d683 (not counted again)
#    EXIT: 2a26b8ac
#    EXIT: 2a26b8ac
#    EXIT: 2a26b8ac
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    EXIT: 0ff9d683
#    NEW: 99d515f5 | Total unique: 86
#    Done: record_20250620_190425.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190525.mp4
#    NEW: 2744c028 | Total unique: 87
#    NEW: ccf8ec4d | Total unique: 88
#    RE-ENTRY: ccf8ec4d (not counted again)
#    RE-ENTRY: ccf8ec4d (not counted again)
#    RE-ENTRY: ccf8ec4d (not counted again)
#    RE-ENTRY: ccf8ec4d (not counted again)
#    NEW: de276e48 | Total unique: 89
#    NEW: ea3cc7a7 | Total unique: 90
#    EXIT: 2744c028
#    EXIT: ccf8ec4d
#    EXIT: ccf8ec4d
#    EXIT: ccf8ec4d
#    EXIT: ccf8ec4d
#    EXIT: ccf8ec4d
#    EXIT: de276e48
#    EXIT: ea3cc7a7
#    Done: record_20250620_190525.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190626.mp4
#    NEW: 460c8a7c | Total unique: 91
#    EXIT: 460c8a7c
#    Done: record_20250620_190626.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190727.mp4
#    NEW: abb696c0 | Total unique: 92
#    EXIT: abb696c0
#    NEW: 0a1fb0e1 | Total unique: 93
#    NEW: ee10b0f8 | Total unique: 94
#    NEW: 3a0302c8 | Total unique: 95
#    EXIT: 0a1fb0e1
#    EXIT: ee10b0f8
#    EXIT: 3a0302c8
#    Done: record_20250620_190727.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190828.mp4
#    NEW: 722e017a | Total unique: 96
#    EXIT: 722e017a
#    NEW: f8c24bce | Total unique: 97
#    NEW: 69cc06e8 | Total unique: 98
#    NEW: 4267a854 | Total unique: 99
#    RE-ENTRY: 4267a854 (not counted again)
#    RE-ENTRY: 4267a854 (not counted again)
#    RE-ENTRY: 4267a854 (not counted again)
#    RE-ENTRY: 4267a854 (not counted again)
#    NEW: 9538fdc2 | Total unique: 100
#    RE-ENTRY: 9538fdc2 (not counted again)
#    EXIT: f8c24bce
#    EXIT: 69cc06e8
#    EXIT: 4267a854
#    EXIT: 4267a854
#    EXIT: 4267a854
#    EXIT: 4267a854
#    EXIT: 4267a854
#    EXIT: 9538fdc2
#    EXIT: 9538fdc2
#    Done: record_20250620_190828.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_190928.mp4
#    NEW: 5fde28c2 | Total unique: 101
#    EXIT: 5fde28c2
#    Done: record_20250620_190928.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_191029.mp4
#    NEW: e4612603 | Total unique: 102
#    Done: record_20250620_191029.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_191129.mp4
#    NEW: ad93f827 | Total unique: 103
#    NEW: 56a3ca69 | Total unique: 104
#    NEW: 972726d4 | Total unique: 105
#    NEW: db5936ce | Total unique: 106
#    EXIT: 56a3ca69
#    EXIT: ad93f827
#    EXIT: 972726d4
#    EXIT: db5936ce
#    Done: record_20250620_191129.mp4 | Frames processed: 1502
#
#  Processing: record_20250620_191230.mp4
#    NEW: f75e482f | Total unique: 107
#    NEW: 08231e87 | Total unique: 108
#    NEW: 91a198b2 | Total unique: 109
#    RE-ENTRY: 91a198b2 (not counted again)
#    RE-ENTRY: 91a198b2 (not counted again)
#    RE-ENTRY: 91a198b2 (not counted again)
#    RE-ENTRY: 91a198b2 (not counted again)
#    RE-ENTRY: 91a198b2 (not counted again)
#    RE-ENTRY: 91a198b2 (not counted again)
#    NEW: 93735941 | Total unique: 110
#    EXIT: f75e482f
#    EXIT: 91a198b2
#    EXIT: 91a198b2
#    EXIT: 91a198b2
#    EXIT: 91a198b2
#    EXIT: 91a198b2
#    EXIT: 91a198b2
#    EXIT: 91a198b2
#    EXIT: 08231e87
#    EXIT: 93735941
#    NEW: 7e6acdbc | Total unique: 111
#    NEW: faedc563 | Total unique: 112
#    NEW: d04db7b5 | Total unique: 113
#    NEW: 069d2f95 | Total unique: 114
#    NEW: 63cd8e6c | Total unique: 115
#    NEW: de69200f | Total unique: 116
#    EXIT: 7e6acdbc
#    EXIT: faedc563
#    EXIT: d04db7b5
#    Done: record_20250620_191230.mp4 | Frames processed: 1502
#
#  Processing: video_sample1.mp4
#    NEW: 4c34bcc1 | Total unique: 117
#    NEW: 20bddc22 | Total unique: 118
#    NEW: 78493ba4 | Total unique: 119
#    NEW: 08424612 | Total unique: 120
#    NEW: 4b9f299e | Total unique: 121
#    NEW: 61fd71c8 | Total unique: 122
#    NEW: 909961f1 | Total unique: 123
#    NEW: 9cf924f8 | Total unique: 124
#    NEW: d3f4cbc9 | Total unique: 125
#    NEW: a51ae9e0 | Total unique: 126
#    NEW: 6ce51fac | Total unique: 127
#    RE-ENTRY: 61fd71c8 (not counted again)
#    NEW: 9124370e | Total unique: 128
#    RE-ENTRY: 6ce51fac (not counted again)
#    NEW: 1e2c5fd7 | Total unique: 129
#    RE-ENTRY: 909961f1 (not counted again)
#    RE-ENTRY: 909961f1 (not counted again)
#    RE-ENTRY: d3f4cbc9 (not counted again)
#    NEW: 6f67fb14 | Total unique: 130
#    RE-ENTRY: 6ce51fac (not counted again)
#    RE-ENTRY: 61fd71c8 (not counted again)
#    RE-ENTRY: 4c34bcc1 (not counted again)
#    NEW: 7790c914 | Total unique: 131
#    NEW: 7cc181c1 | Total unique: 132
#    NEW: 68a7aeee | Total unique: 133
#    RE-ENTRY: 6ce51fac (not counted again)
#    NEW: e533aee5 | Total unique: 134
#    NEW: 7c7344af | Total unique: 135
#    NEW: f9305562 | Total unique: 136
#    NEW: 253bca77 | Total unique: 137
#    RE-ENTRY: 909961f1 (not counted again)
#    RE-ENTRY: 6ce51fac (not counted again)
#    RE-ENTRY: d3f4cbc9 (not counted again)
#    NEW: c9e387c2 | Total unique: 138
#    NEW: 3c4aa168 | Total unique: 139
#    NEW: 48e32961 | Total unique: 140
#    NEW: ecc5e9ca | Total unique: 141
#    NEW: e71972f6 | Total unique: 142
#    RE-ENTRY: d3f4cbc9 (not counted again)
#    NEW: e0f7a429 | Total unique: 143
#    NEW: c0c3a4cf | Total unique: 144
#    RE-ENTRY: 909961f1 (not counted again)
#    RE-ENTRY: 48e32961 (not counted again)
#    RE-ENTRY: 61fd71c8 (not counted again)
#    RE-ENTRY: d3f4cbc9 (not counted again)
#    NEW: 3ac2cfef | Total unique: 145
#    RE-ENTRY: 61fd71c8 (not counted again)
#    RE-ENTRY: 48e32961 (not counted again)
#    RE-ENTRY: 6ce51fac (not counted again)
#    RE-ENTRY: 909961f1 (not counted again)
#    RE-ENTRY: 48e32961 (not counted again)
#    RE-ENTRY: 909961f1 (not counted again)
#    NEW: 58361216 | Total unique: 146
#    NEW: 3c0ec0f2 | Total unique: 147
#    NEW: e40b8aee | Total unique: 148
#    NEW: 293eef68 | Total unique: 149
#    NEW: c3263384 | Total unique: 150
#    NEW: 60696477 | Total unique: 151
#    NEW: 41010d5d | Total unique: 152
#    RE-ENTRY: c3263384 (not counted again)
#    NEW: 5d2410ad | Total unique: 153
#    NEW: 1e9b71f0 | Total unique: 154
#    NEW: 35113fc5 | Total unique: 155
#    NEW: c93def98 | Total unique: 156
#    NEW: cc9cbb90 | Total unique: 157
#    NEW: cc44e6bb | Total unique: 158
#    NEW: b6243ecb | Total unique: 159
#    EXIT: 4b9f299e
#    NEW: 157da3e1 | Total unique: 160
#    NEW: 5e152240 | Total unique: 161
#    NEW: de188147 | Total unique: 162
#    NEW: 5d8cfad0 | Total unique: 163
#    NEW: 91c51aa5 | Total unique: 164
#    NEW: 95eaddf4 | Total unique: 165
#    EXIT: 909961f1
#    EXIT: a51ae9e0
#    RE-ENTRY: cc9cbb90 (not counted again)
#    NEW: bcff34c9 | Total unique: 166
#    EXIT: 61fd71c8
#    EXIT: 4c34bcc1
#    RE-ENTRY: bcff34c9 (not counted again)
#    EXIT: 6ce51fac
#    RE-ENTRY: 1e9b71f0 (not counted again)
#    RE-ENTRY: bcff34c9 (not counted again)
#    EXIT: 909961f1
#    RE-ENTRY: bcff34c9 (not counted again)
#    EXIT: 6f67fb14
#    RE-ENTRY: bcff34c9 (not counted again)
#    NEW: 43c35f87 | Total unique: 167
#    EXIT: 9cf924f8
#    RE-ENTRY: bcff34c9 (not counted again)
#    EXIT: 1e2c5fd7
#    EXIT: 909961f1
#    NEW: 0006ea41 | Total unique: 168
#    EXIT: 68a7aeee
#    EXIT: 6ce51fac
#    NEW: 18018674 | Total unique: 169
#    NEW: 9ced264c | Total unique: 170
#    EXIT: 7cc181c1
#    EXIT: 6ce51fac
#    RE-ENTRY: 0006ea41 (not counted again)
#    EXIT: 253bca77
#    EXIT: 909961f1
#    RE-ENTRY: 9ced264c (not counted again)
#    RE-ENTRY: 18018674 (not counted again)
#    EXIT: f9305562
#    NEW: 5724270f | Total unique: 171
#    NEW: 0c627c99 | Total unique: 172
#    NEW: d69320d0 | Total unique: 173
#    EXIT: c9e387c2
#    Done: video_sample1.mp4 | Frames processed: 240
#
#
#  ALL DONE!
#  Total Unique Visitors: 173
#
#  PER VIDEO SUMMARY:
# --------------------------------------------------
#   record_20250620_183903.mp4: 42 entries
#   record_20250620_184049.mp4: 2 entries
#   record_20250620_184302.mp4: 2 entries
#   record_20250620_184403.mp4: 9 entries
#   record_20250620_184504.mp4: 8 entries
#   record_20250620_184705.mp4: 1 entries
#   record_20250620_184807.mp4: 30 entries
#   record_20250620_184907.mp4: 3 entries
#   record_20250620_185008.mp4: 9 entries
#   record_20250620_185109.mp4: 1 entries
#   record_20250620_185210.mp4: 10 entries
#   record_20250620_190324.mp4: 24 entries
#   record_20250620_190425.mp4: 13 entries
#   record_20250620_190525.mp4: 8 entries
#   record_20250620_190626.mp4: 1 entries
#   record_20250620_190727.mp4: 4 entries
#   record_20250620_190828.mp4: 10 entries
#   record_20250620_190928.mp4: 1 entries
#   record_20250620_191029.mp4: 1 entries
#   record_20250620_191129.mp4: 4 entries
#   record_20250620_191230.mp4: 16 entries
#   video_sample1.mp4: 91 entries
# --------------------------------------------------

# %%
import shutil

shutil.copy(
    '/content/face_tracker/visitors.db',
    '/content/drive/MyDrive/visitors.db'
)
shutil.copytree(
    '/content/face_tracker/logs',
    '/content/drive/MyDrive/face_tracker_logs',
    dirs_exist_ok=True
)
shutil.copy(
    '/content/face_tracker/config.json',
    '/content/drive/MyDrive/config.json'
)
print(" DB, logs, and config saved to Drive!")
# Out:
#  DB, logs, and config saved to Drive!

# %%
import json as jsonlib

embeddings_backup = {}
for face_id, emb in recognizer.known_faces.items():
    embeddings_backup[face_id] = emb.tolist()

with open('/content/drive/MyDrive/embeddings_backup.json', 'w') as f:
    jsonlib.dump(embeddings_backup, f)

print(f" Saved {len(embeddings_backup)} embeddings to Drive!")
# Out:
#  Saved 139 embeddings to Drive!

# %%
import pandas as pd

print("=" * 60)
print("              VERIFICATION REPORT")
print("=" * 60)

df  = pd.read_sql_query("SELECT * FROM visitors", conn)
uv  = pd.read_sql_query("SELECT * FROM unique_visitors", conn)
emb = pd.read_sql_query("SELECT COUNT(*) as count FROM embeddings", conn)

print(f"\n DATABASE CHECK")
print(f"  Total events logged  : {len(df)}")
print(f"  Unique visitors      : {get_unique_count(conn)}")
print(f"  Entry events         : {len(df[df['event_type']=='entry'])}")
print(f"  Exit events          : {len(df[df['event_type']=='exit'])}")
print(f"  Saved embeddings     : {emb['count'][0]}")
print(f"  Videos covered       : {df['video_file'].nunique()}")

missing = sum(
    1 for _, row in df[df['event_type'] == 'entry'].iterrows()
    if not row['image_path'] or not os.path.exists(str(row['image_path']))
)
exit_imgs = sum(
    1 for _, row in df[df['event_type'] == 'exit'].iterrows()
    if row['image_path'] and os.path.exists(str(row['image_path']))
)
print(f"\n  IMAGE CHECK")
print(f"  Entry images saved   : {len(df[df['event_type']=='entry']) - missing}")
print(f"  Missing entry images : {missing}")
print(f"  Exit images saved    : {exit_imgs}")

log_path = '/content/face_tracker/logs/events.log'
if os.path.exists(log_path):
    with open(log_path) as f:
        lines = f.readlines()
    print(f"\n LOG FILE CHECK")
    print(f"  Total log lines          : {len(lines)}")
    print(f"  ENTRY                    : {sum(1 for l in lines if 'ENTRY' in l)}")
    print(f"  EXIT                     : {sum(1 for l in lines if 'EXIT' in l)}")
    print(f"  TRACKING                 : {sum(1 for l in lines if 'TRACKING' in l)}")
    print(f"  EMBEDDING_GENERATED      : {sum(1 for l in lines if 'EMBEDDING' in l)}")
    print(f"  RE_IDENTIFIED            : {sum(1 for l in lines if 'RE_IDENTIFIED' in l)}")
else:
    print("\n Log file not found!")

entry_counts = df[df['event_type'] == 'entry']['face_id'].value_counts()
duplicates   = entry_counts[entry_counts > 1]
print(f"\n DUPLICATE CHECK")
if len(duplicates) == 0:
    print(f"   No face registered twice as unique!")
else:
    print(f"    {len(duplicates)} face IDs appear in more than one entry")
    print(f"     (These are re-entries — expected behaviour)")

print(f"\n SAMPLE ENTRIES (first 5)")
print(df[df['event_type'] == 'entry'][
    ['face_id', 'timestamp', 'video_file']
].head().to_string())

print(f"\n{'=' * 60}")
print(" VERIFICATION COMPLETE")
print("=" * 60)
# Out:
# ============================================================
#               VERIFICATION REPORT
# ============================================================
#
#  DATABASE CHECK
#   Total events logged  : 580
#   Unique visitors      : 173
#   Entry events         : 290
#   Exit events          : 290
#   Saved embeddings     : 139
#   Videos covered       : 22
#
#   IMAGE CHECK
#   Entry images saved   : 269
#   Missing entry images : 21
#   Exit images saved    : 269
#
#  Log file not found!
#
#  DUPLICATE CHECK
#     42 face IDs appear in more than one entry
#      (These are re-entries — expected behaviour)
#
#  SAMPLE ENTRIES (first 5)
#     face_id            timestamp                  video_file
# 0  82e08fd7  2026-03-22 15:57:45  record_20250620_183903.mp4
# 2  55889152  2026-03-22 15:58:06  record_20250620_183903.mp4
# 3  3447534a  2026-03-22 15:58:08  record_20250620_183903.mp4
# 4  4e6615c7  2026-03-22 15:58:11  record_20250620_183903.mp4
# 5  90ed8720  2026-03-22 15:58:13  record_20250620_183903.mp4
#
# ============================================================
#  VERIFICATION COMPLETE
# ============================================================

# %%
lines = [
    "import streamlit as st\n",
    "import sqlite3\n",
    "import pandas as pd\n",
    "import os\n",
    "from PIL import Image\n",
    "\n",
    "st.set_page_config(page_title='Face Tracker Dashboard', layout='wide')\n",
    "st.title('Intelligent Face Tracker Dashboard')\n",
    "st.markdown('YOLO + InsightFace + Centroid Tracker | Unique Visitor Counter')\n",
    "st.divider()\n",
    "\n",
    "DB_PATH = '/content/face_tracker/visitors.db'\n",
    "\n",
    "def load_data():\n",
    "    conn = sqlite3.connect(DB_PATH)\n",
    "    df = pd.read_sql_query('SELECT * FROM visitors ORDER BY timestamp ASC', conn)\n",
    "    uv = pd.read_sql_query('SELECT * FROM unique_visitors ORDER BY first_seen', conn)\n",
    "    conn.close()\n",
    "    return df, uv\n",
    "\n",
    "df, uv = load_data()\n",
    "\n",
    "c1, c2, c3, c4 = st.columns(4)\n",
    "c1.metric('Unique Visitors', len(uv))\n",
    "c2.metric('Videos Processed', df['video_file'].nunique())\n",
    "c3.metric('Entry Events', len(df[df['event_type'] == 'entry']))\n",
    "c4.metric('Exit Events', len(df[df['event_type'] == 'exit']))\n",
    "st.divider()\n",
    "\n",
    "st.subheader('Filter by Video')\n",
    "vids = ['All Videos'] + sorted(df['video_file'].unique().tolist())\n",
    "sel_vid = st.selectbox('Select Video', vids)\n",
    "fdf = df.copy()\n",
    "if sel_vid != 'All Videos':\n",
    "    fdf = fdf[fdf['video_file'] == sel_vid]\n",
    "st.divider()\n",
    "\n",
    "st.subheader('Detected Faces Gallery')\n",
    "visible_faces = (\n",
    "    fdf[fdf['event_type'] == 'entry']\n",
    "    .sort_values('timestamp')\n",
    "    .drop_duplicates(subset='face_id', keep='first')\n",
    "    .head(12)\n",
    ")\n",
    "cols = st.columns(6)\n",
    "shown = 0\n",
    "for _, row in visible_faces.iterrows():\n",
    "    path = str(row['image_path']) if row['image_path'] else ''\n",
    "    if path and os.path.exists(path):\n",
    "        with cols[shown % 6]:\n",
    "            img = Image.open(path)\n",
    "            fid = row['face_id'][:6]\n",
    "            st.image(img, caption='ID: ' + fid, use_container_width=True)\n",
    "        shown += 1\n",
    "    if shown >= 12:\n",
    "        break\n",
    "if shown == 0:\n",
    "    st.info('No face images found.')\n",
    "st.divider()\n",
    "\n",
    "st.subheader('Visitor Timeline by Hour')\n",
    "if not fdf.empty:\n",
    "    plot_df = fdf.copy()\n",
    "    plot_df['hour'] = pd.to_datetime(plot_df['timestamp'], errors='coerce').dt.hour\n",
    "    tl = (\n",
    "        plot_df[plot_df['event_type'] == 'entry']\n",
    "        .drop_duplicates(subset='face_id')\n",
    "        .groupby('hour')\n",
    "        .size()\n",
    "        .reset_index(name='visitors')\n",
    "    )\n",
    "    if not tl.empty:\n",
    "        st.bar_chart(tl.set_index('hour'))\n",
    "    else:\n",
    "        st.info('No data to plot.')\n",
    "st.divider()\n",
    "\n",
    "st.subheader('Event Log')\n",
    "st.dataframe(\n",
    "    fdf[fdf['event_type'] == 'entry'][['face_id', 'timestamp', 'video_file']],\n",
    "    use_container_width=True,\n",
    "    height=350\n",
    ")\n",
    "\n",
    "st.subheader('Unique Visitors Registry')\n",
    "st.dataframe(uv, use_container_width=True, height=300)\n",
    "st.divider()\n",
    "\n",
    "csv = fdf.to_csv(index=False)\n",
    "st.download_button('Download Event Log as CSV', csv, 'visitor_log.csv', 'text/csv')\n",
    "st.markdown('---')\n",
    "st.caption('This project is a part of a hackathon run by https://katomaran.com')\n",
]

with open('/content/face_tracker/app.py', 'w') as f:
    f.writelines(lines)
print("app.py updated!")
# Out:
# app.py updated!

# %%
ngrok_token = input("Paste your ngrok authtoken: ")
# !ngrok authtoken {ngrok_token}

from pyngrok import ngrok
import subprocess, time

subprocess.run(['pkill', '-f', 'streamlit'], capture_output=True)
time.sleep(2)

proc = subprocess.Popen([
    'streamlit', 'run', '/content/face_tracker/app.py',
    '--server.port', '8501',
    '--server.headless', 'true'
])
time.sleep(5)

url = ngrok.connect(8501)
print(f"\n Dashboard is LIVE at: {url}")
print(" Click the link above to open your dashboard!")
# Out:
# Paste your ngrok authtoken: 3BFseF5xhKgIjnaK2t6sdZV2fdQ_4LoYTm5xqPXssiZJhhUh4
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
#
#  Dashboard is LIVE at: NgrokTunnel: "https://oda-extinct-allegra.ngrok-free.dev" -> "http://localhost:8501"
#  Click the link above to open your dashboard!
